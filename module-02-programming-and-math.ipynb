# %% [markdown]
# <a href="https://colab.research.google.com/github/AsalBotirova/ai-ml-course/blob/main/module-02-programming-and-math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Set Up Google **Colab**
# What to do: Create a new Colab notebook and name it properly.

# %%
print("Hello, AI/ML!")
# Out:
# Hello, AI/ML!

# %% [markdown]
# Task 2: Variables and Data Types
# What to do: Create 5 variables (one of each type: int, float, string, bool, list) and print each with its type.

# %%
age = 18
gpa = 3.85
name = "Asal"
is_student = True
scores = [85, 92, 78, 95, 88]

print(age, type(age))
print(gpa, type(gpa))
print(name, type(name))
print(is_student, type(is_student))
print(scores, type(scores))
# Out:
# 18 <class 'int'>
# 3.85 <class 'float'>
# Asal <class 'str'>
# True <class 'bool'>
# [85, 92, 78, 95, 88] <class 'list'>

# %% [markdown]
# Task 3: Write a Function
# What to do: Write a function called calculate_average that takes a list of numbers and returns the average. Tenst it with at least 2 different lists.

# %%
def calculate_average(numbers):
  total = sum(numbers)
  count = len(numbers)
  return total/count

test1 = [80, 90, 70, 85, 95]
test2 = [55, 62, 48, 71]
print("Average 1:", calculate_average(test1))
print("Average 2:", calculate_average(test2))
# Out:
# Average 1: 84.0
# Average 2: 59.0

# %% [markdown]
# Task 4: Loops with enumerate()
# What to do: Write a for loop that iterates over a list of at least 5 items and prints each item with its index.

# %%
cities = ["Tashkent", "Samarkand", "Bukhara", "Namangan", "Fergana"]
for index, city in enumerate(cities):
  print(f"Index {index}: {city}")
# Out:
# Index 0: Tashkent
# Index 1: Samarkand
# Index 2: Bukhara
# Index 3: Namangan
# Index 4: Fergana

# %% [markdown]
# Task 5: Combine Everything
# What to do: Create a list of 10 random exam scores (integers 0-100), calculate the average, and print whether the class passed or failed (threshold: 60).

# %%
import random
exam_scores = [random.randint(0,100) for _ in range(10)]
print(f"Scores: {exam_scores}")

avg = calculate_average(exam_scores)
print(f"Average: {avg:.1f}")

if avg>=60:
  print("Result: PASS")
else:
  print("Result: FAIL")
# Out:
# Scores: [93, 11, 5, 40, 86, 25, 29, 86, 95, 15]
# Average: 48.5
# Result: FAIL
